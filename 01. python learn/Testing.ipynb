# %% [markdown]
# ## Ejecutando comandos

# %%
# !ls
# !echo '========'
# !ls ../
# Out:
# Testing.ipynb
# ...
# 01. python learn            personalizing
# Hyperskill-Python-Basic.iml resources
# README.md                   venv

# %% [markdown]
# <h1 style="color:green"> Este es un titulo </h1> <br><br>
#
# Machine **learning** y redes *neuronales*

# %% [markdown]
# ### Ejemplo con LaTex

# %% [markdown]
# $f(x) = x^2$
#
# <h3 style="color:green">$f(x) = x^2$</h3>

# %%
### Agregar graficos

from matplotlib.pyplot import plot

plot([0,1,0,1])
